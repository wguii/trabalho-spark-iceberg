# %%
from pyspark.sql.functions import col


source_table = "sua_tabela"

df_bronze = spark.table(f"bronze.{source_table}_cleaned")

df_silver = df_bronze.filter(col("status") == "ativo")

df_silver.write.format("delta").mode("overwrite").saveAsTable(f"silver.{source_table}_curated")
